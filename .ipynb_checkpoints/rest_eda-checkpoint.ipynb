# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import re

# %%
reviews_df=pd.read_csv('data-yelp/yelp_review.csv')

# %%
reviews_df.describe()
# Out:
#               stars        useful         funny          cool
# count  5.261668e+06  5.261668e+06  5.261668e+06  5.261668e+06
# mean   3.727739e+00  1.385085e+00  5.091961e-01  5.860917e-01
# std    1.433593e+00  4.528727e+00  2.686168e+00  2.233706e+00
# min    1.000000e+00 -1.000000e+00  0.000000e+00 -1.000000e+00
# 25%    3.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    4.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    5.000000e+00  2.000000e+00  0.000000e+00  1.000000e+00
# max    5.000000e+00  3.364000e+03  1.481000e+03  1.105000e+03

# %%
reviews_df.keys()
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars', 'date', 'text',
#        'useful', 'funny', 'cool'],
#       dtype='object')

# %%
str=reviews_df['text'][0]

# %%
spliter=re.compile('[.\'\n0-9\:]|It\'s| and | the | was | with | but | been | since | still | the ')

# %%
str
# Out:
# "Super simple place but amazing nonetheless. It's been around since the 30's and they still serve the same thing they started with: a bologna and salami sandwich with mustard. \n\nStaff was very helpful and friendly."

# %%
sample=spliter.sub(' ',str)

# %%
sample
# Out:
# 'Super simple place amazing nonetheless    around the    s they serve same thing they started with  a bologna salami sandwich mustard    Staff very helpful friendly '

# %%
sample.split()
# Out:
# ['Super',
#  'simple',
#  'place',
#  'amazing',
#  'nonetheless',
#  'around',
#  'the',
#  's',
#  'they',
#  'serve',
#  'same',
#  'thing',
#  'they',
#  'started',
#  'with',
#  'a',
#  'bologna',
#  'salami',
#  'sandwich',
#  'mustard',
#  'Staff',
#  'very',
#  'helpful',
#  'friendly']

# %%
re_sa=re.compile(' a | s ')
sample=re_sa.sub(' ',sample)

# %%
sample
# Out:
# 'Super simple place amazing nonetheless    around the    they serve same thing they started with  bologna salami sandwich mustard    Staff very helpful friendly '

# %%
sample_list=sample.split()

# %%
sample_list
# Out:
# ['Super',
#  'simple',
#  'place',
#  'amazing',
#  'nonetheless',
#  'around',
#  'the',
#  'they',
#  'serve',
#  'same',
#  'thing',
#  'they',
#  'started',
#  'with',
#  'bologna',
#  'salami',
#  'sandwich',
#  'mustard',
#  'Staff',
#  'very',
#  'helpful',
#  'friendly']

# %%
reviews_df.describe(include='all')
# Out:
#                      review_id                 user_id  \
# count                  5261668                 5261668
# unique                 5261668                 1326101
# top     iePPxOBfZlBpuCu4f-Kc-g  CxDOIDnH8gp9KXzpBHJYXw
# freq                         1                    3569
# mean                       NaN                     NaN
# std                        NaN                     NaN
# min                        NaN                     NaN
# 25%                        NaN                     NaN
# 50%                        NaN                     NaN
# 75%                        NaN                     NaN
# max                        NaN                     NaN
#
#                    business_id         stars        date  \
# count                  5261668  5.261668e+06     5261668
# unique                  174567           NaN        4547
# top     4JNXUYY8wbaaDmk3BPzlWw           NaN  2017-08-12
# freq                      7362           NaN        4614
# ...

# %%
busi_df=pd.read_csv('data-yelp/yelp_business.csv')

# %%
busi_df.keys()
# Out:
# Index(['business_id', 'name', 'neighborhood', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars', 'review_count',
#        'is_open', 'categories'],
#       dtype='object')

# %%
busi_df.describe(include='all')
# Out:
#                    business_id         name neighborhood address       city  \
# count                   174567       174567        68015  174567     174566
# unique                  174567       132619          408  138564       1093
# top     pbtrEH8x8Jp4fIRQ6mVOPQ  "Starbucks"     Westside      ""  Las Vegas
# freq                         1          936         3500    6442      26775
# mean                       NaN          NaN          NaN     NaN        NaN
# std                        NaN          NaN          NaN     NaN        NaN
# min                        NaN          NaN          NaN     NaN        NaN
# 25%                        NaN          NaN          NaN     NaN        NaN
# 50%                        NaN          NaN          NaN     NaN        NaN
# 75%                        NaN          NaN          NaN     NaN        NaN
# max                        NaN          NaN          NaN     NaN        NaN
#
# ...

# %%
busi_attr_df=pd.read_csv('data-yelp/yelp_business_attributes.csv')

# %%
busi_attr_df.keys()
# Out:
# Index(['business_id', 'AcceptsInsurance', 'ByAppointmentOnly',
#        'BusinessAcceptsCreditCards', 'BusinessParking_garage',
#        'BusinessParking_street', 'BusinessParking_validated',
#        'BusinessParking_lot', 'BusinessParking_valet',
#        'HairSpecializesIn_coloring', 'HairSpecializesIn_africanamerican',
#        'HairSpecializesIn_curly', 'HairSpecializesIn_perms',
#        'HairSpecializesIn_kids', 'HairSpecializesIn_extensions',
#        'HairSpecializesIn_asian', 'HairSpecializesIn_straightperms',
#        'RestaurantsPriceRange2', 'GoodForKids', 'WheelchairAccessible',
#        'BikeParking', 'Alcohol', 'HasTV', 'NoiseLevel', 'RestaurantsAttire',
#        'Music_dj', 'Music_background_music', 'Music_no_music', 'Music_karaoke',
#        'Music_live', 'Music_video', 'Music_jukebox', 'Ambience_romantic',
#        'Ambience_intimate', 'Ambience_classy', 'Ambience_hipster',
#        'Ambience_divey', 'Ambience_touristy', 'Ambience_trendy',
# ...

# %%
busi_attr_df.describe(include='all')
# Out:
#                    business_id AcceptsInsurance ByAppointmentOnly  \
# count                   152041           152041            152041
# unique                  152041                1                 3
# top     U8c5AcNhWq1koQwNyzMqkw               Na                Na
# freq                         1           152041            151946
#
#        BusinessAcceptsCreditCards BusinessParking_garage  \
# count                      152041                 152041
# unique                          3                      3
# top                            Na                     Na
# freq                       128460                 131649
#
#        BusinessParking_street BusinessParking_validated BusinessParking_lot  \
# count                  152041                    152041              152041
# unique                      3                         3                   3
# top                        Na                        Na                  Na
# ...

# %%
user_df=pd.read_csv('data-yelp/yelp_user.csv')

# %%
user_df.keys()
# Out:
# Index(['user_id', 'name', 'review_count', 'yelping_since', 'friends', 'useful',
#        'funny', 'cool', 'fans', 'elite', 'average_stars', 'compliment_hot',
#        'compliment_more', 'compliment_profile', 'compliment_cute',
#        'compliment_list', 'compliment_note', 'compliment_plain',
#        'compliment_cool', 'compliment_funny', 'compliment_writer',
#        'compliment_photos'],
#       dtype='object')

# %%
user_df.describe(include='all')
# Out:
#                        user_id     name  review_count yelping_since  friends  \
# count                  1326100  1325603  1.326100e+06       1326100  1326100
# unique                 1326100   113960           NaN          4699   748104
# top     qJYuMlBjoJFm8naEOp7odQ     John           NaN    2015-10-17     None
# freq                         1    11763           NaN           791   566093
# mean                       NaN      NaN  2.311717e+01           NaN      NaN
# std                        NaN      NaN  7.909808e+01           NaN      NaN
# min                        NaN      NaN  0.000000e+00           NaN      NaN
# 25%                        NaN      NaN  2.000000e+00           NaN      NaN
# 50%                        NaN      NaN  5.000000e+00           NaN      NaN
# 75%                        NaN      NaN  1.500000e+01           NaN      NaN
# max                        NaN      NaN  1.195400e+04           NaN      NaN
#
# ...

# %%
len(user_df)
# Out:
# 1326100

# %%
user_reduced=user_df[user_df['review_count']>4]

# %%
user_reduced.iloc[0]
# Out:
# user_id                                          JJ-aSuM4pCFPdkfoZ34q0Q
# name                                                              Chris
# review_count                                                         10
# yelping_since                                                2013-09-24
# friends               0njfJmB-7n84DlIgUByCNw, rFn3Xe3RqHxRSxWOU19Gpg...
# useful                                                                0
# funny                                                                 0
# cool                                                                  0
# fans                                                                  0
# elite                                                              None
# average_stars                                                       3.7
# compliment_hot                                                        0
# compliment_more                                                       0
# ...

# %%
user_list=[elem['user_id'] for idx,elem in user_reduced.iterrows()]

# %%
user_list[0]
# Out:
# 'JJ-aSuM4pCFPdkfoZ34q0Q'

# %%
reviews_df.keys()
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars', 'date', 'text',
#        'useful', 'funny', 'cool'],
#       dtype='object')

# %%
reviews_df=reviews_df.drop(['review_id','business_id','date','useful','funny','cool'],axis=1)

# %%
reviews_df=reviews_df[reviews_df['stars']!=3]

# %%
len(reviews_df)
# Out:
# 4646187

# %%
data_all=[]
for user,review in reviews_df.groupby('user_id'):
    if user not in user_list:
        continue
    high=False
    low=False
    data=[]
    review=review.drop('user_id',axis=1)
    for item in review.iterrows():
        print(item)
        stars=item['stars']
        if not high:
            if stars==4 or stars==5:
                data.append({'text':item.text,'stars':(stars-1)*0.25})
                high=True
        if not low:
            if stars==1 or stars==2:
                data.appen({'text':item.text,'stars':(stars-1)*0.25})
                low=True
        if high and low:
            break
    if high and low: # only add review data for user which has high and low both
        data_all+=data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index([3632426, 3632427, 3632428, 3632429, 3632430, 3632431, 3632432,
#             3632433, 3632435, 3632436,
#             ...
#             4583144, 4583145, 4583146, 4583147, 4583148, 4583149, 4583150,
#             4583151, 4583152, 4583153],
#            dtype='int64', length=109)
# Index(['stars', 'text'], dtype='object')
# stars
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-69f43db96696> in <module>
#      12     for item in review:
#      13         print(item)
# ---> 14         stars=item['stars']
#      15         if not high:
#      16             if stars==4 or stars==5:
#
# TypeError: string indices must be integers
